# %%
import os
import tweepy as tw
import pandas as pd
# look at twarkk
# look at vader -- for social media data
#

# %%
# insert APIs here

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %% [markdown]
# I need to decide which sources I want to pull my tweets from. There are four different sources that I am considering: Financial Advisors, News Sources, Company, Company Executives.

# %% [markdown]
# ### Tweet Sources

# %% [markdown]
# #### Tweets from Financial Advisors, News Sources, and Others
# ##### Key Terms to Search
# * "tesla"
# * "stock"
# * "elon"
# * "musk"

# %% [markdown]
# #### Tweets from the Company and Company Executives
# * Tesla : @Tesla
# * Elon Musk : @elonmusk

# %%
# What dates that we want to grab? These dates are from Nov 18, 2015 to Nov 18, 2020
dates = [pd.read_csv('TSLAstocks.csv').Date][0]

# %%
# Define the search term and the date_since date as variables
search_words = "Tesla" + " -filter:retweets"
start_date = '2020-11-18'
num_tweets = 1000

# %%
dates[1000:1002]
# Out:
# 1000    2019-11-08
# 1001    2019-11-11
# Name: Date, dtype: object

# %%
# grab screen_name and location
tweets = tw.Cursor(api.search,
                       q=search_words,
                       lang="en",
                       until=start_date,
                       result_type="popular").items(num_tweets)

tweet_info = [[tweet.text,
               tweet.user.screen_name, 
               tweet.user.location, 
               tweet.created_at] for tweet in tweets]

# %%
#create a pandas df from a list of tweet data
tweet_info = pd.DataFrame(data=tweet_info,
                         columns=['txt', 'user', 'location', 'date'])
tweet_info
# Out:
#                                                   txt            user  \
# 0   .@bts_bighit, our 2020 Music Innovator, has re...          WSJMag
# 1   “That feeling [of being onstage] is really the...          WSJMag
# 2   .@bts_bighit's new album is out this month, an...          WSJMag
# 3   Elon Musk, who famously predicted the coronavi...         RBReich
# 4   Elon Musk reportedly fired Tesla workers who w...         RBReich
# 5   I'm obsessed with our photos of @bts_bighit. e...     mylestanzer
# 6   Elon Musk now richer than Mark Zuckerberg as T...          nypost
# 7   VIDEO: The three largest #glaciers in #Greenla...             AFP
# 8   Tesla CEO Elon Musk questioned the accuracy of...         Reuters
# 9   Order solar panels before the solar tax credit...           Tesla
# 10  I wonder if a case of Tesla Tequila will now c...  officialmcafee
# 11  Joe Biden will bring something that manufactur...        business
# ...

# %%
# you could count the number of retweets on a tweet and have that as a predictor variable
# i wonder if I could pull the number of followers from the person who tweeted it

# look up twitter api documentation
# I could also grab new sources tweets
